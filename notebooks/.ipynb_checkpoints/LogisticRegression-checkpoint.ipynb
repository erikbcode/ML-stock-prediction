# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import ppscore as ps
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
import pandas_datareader
from datetime import date

# %% [markdown]
# # In this notebook, we will use Logistic Regression techniques to perform a prediction on whether a stock will move up or down on the next day

# %%
# Load in intitial datasets
ticker = 'aapl'
startdate = '1990-01-01'
aapl = pandas_datareader.DataReader(ticker.lower(), 'yahoo', start=startdate, end = date.today().strftime("%Y-%m-%d"))
aapl.reset_index(inplace=True)

ticker = '^vix'
startdate = '1990-01-01'
vix = pandas_datareader.DataReader(ticker.lower(), 'yahoo', start=startdate, end = date.today().strftime("%Y-%m-%d"))
vix.reset_index(inplace=True)

# %% [markdown]
# ### Data cleaning

# %%
vix.drop(['Volume', 'High', 'Low', 'Close', 'Open', 'Volume'], axis=1, inplace=True)
vix.rename(columns={'Adj Close': 'VIX_AdjClose'}, inplace=True)

# %%
# Get the means of columns with any missing values 
# Could make this a mean within 10 values surrounding possibly
def get_missing_values(df):
    values = {}
    for feat in df.columns:
        if df[feat].isna().any():
            values[feat] = round(df[feat].mean(),3)
    return values

values = get_missing_values(aapl)
values
# Out:
# {}

# %%
len(vix)
# Out:
# 8294

# %%
vix.head()
# Out:
#         Date  VIX_AdjClose
# 0 1990-01-02     17.240000
# 1 1990-01-03     18.190001
# 2 1990-01-04     19.219999
# 3 1990-01-05     20.110001
# 4 1990-01-08     20.260000

# %%
len(aapl)
# Out:
# 8294

# %%
# Fill empty values and display heatmap
aapl.fillna(value=values, inplace=True)
sns.heatmap(aapl.isnull(), yticklabels=False, cbar=False)
# Out:
# <AxesSubplot:>

# %%
# Fill empty values and display heatmap
aapl.fillna(value=values, inplace=True)
sns.heatmap(vix.isnull(), yticklabels=False, cbar=False)
# Out:
# <AxesSubplot:>

# %%
# Summary of columns with null values 
Sum = aapl.isnull().sum()
Percentage = (aapl.isnull().sum()/aapl.isnull().count())

pd.concat([Sum,Percentage], axis =1, keys= ['Sum', 'Percentage'])
# Out:
#            Sum  Percentage
# Date         0         0.0
# High         0         0.0
# Low          0         0.0
# Open         0         0.0
# Close        0         0.0
# Volume       0         0.0
# Adj Close    0         0.0

# %%
# Turn date into datetime
aapl['Date'] = pd.to_datetime(aapl.Date)
vix['Date'] = pd.to_datetime(vix.Date)
df = aapl.merge(vix, how='inner', on=['Date'])

# %%
df.head()
# Out:
#         Date      High       Low      Open     Close       Volume  Adj Close  \
# 0 1990-01-02  0.334821  0.312500  0.314732  0.332589  183198400.0   0.264886
# 1 1990-01-03  0.339286  0.334821  0.339286  0.334821  207995200.0   0.266664
# 2 1990-01-04  0.345982  0.332589  0.341518  0.335938  221513600.0   0.267553
# 3 1990-01-05  0.341518  0.330357  0.337054  0.337054  123312000.0   0.268442
# 4 1990-01-08  0.339286  0.330357  0.334821  0.339286  101572800.0   0.270220
#
#    VIX_AdjClose
# 0     17.240000
# 1     18.190001
# 2     19.219999
# 3     20.110001
# 4     20.260000

# %%
df.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  8294.000000  8294.000000  8294.000000  8294.000000  8.294000e+03
# mean     20.882427    20.417182    20.647886    20.658945  3.742941e+08
# std      38.533628    37.623135    38.069583    38.098027  3.612823e+08
# min       0.118304     0.113839     0.114955     0.115513  2.396800e+06
# 25%       0.379464     0.363862     0.372238     0.371250  1.398152e+08
# 50%       2.550535     2.455178     2.515893     2.505714  2.570966e+08
# 75%      24.211874    23.786786    24.000000    24.021250  4.692296e+08
# max     182.940002   179.119995   182.630005   182.009995  7.421641e+09
#
#          Adj Close  VIX_AdjClose
# count  8294.000000   8294.000000
# mean     19.813951     19.659512
# std      37.799496      8.003070
# min       0.098465      9.140000
# 25%       0.311081     13.860000
# 50%       2.135915     17.799999
# 75%      21.688090     23.170000
# max     180.959732     82.690002

# %%
df = df[['Date', 'Adj Close']].copy()
df.rename(columns={'Adj Close': 'Close'}, inplace=True)
df
# Out:
#            Date       Close
# 0    1990-01-02    0.264886
# 1    1990-01-03    0.266664
# 2    1990-01-04    0.267553
# 3    1990-01-05    0.268442
# 4    1990-01-08    0.270220
# ...         ...         ...
# 8289 2022-11-23  151.070007
# 8290 2022-11-25  148.110001
# 8291 2022-11-28  144.220001
# 8292 2022-11-29  141.169998
# 8293 2022-11-30  148.029999
#
# [8294 rows x 2 columns]

# %%
# Get series' of 3 weeks days ago days of lagging prices for logistic regression
for i in range(1, 11):
    df['Trailing ' + str(i) + ' day(s)'] = df['Close'].shift(i)

# %%
df
# Out:
#            Date       Close  Trailing 1 day(s)  Trailing 2 day(s)  \
# 0    1990-01-02    0.264886                NaN                NaN
# 1    1990-01-03    0.266664           0.264886                NaN
# 2    1990-01-04    0.267553           0.266664           0.264886
# 3    1990-01-05    0.268442           0.267553           0.266664
# 4    1990-01-08    0.270220           0.268442           0.267553
# ...         ...         ...                ...                ...
# 8289 2022-11-23  151.070007         150.179993         148.009995
# 8290 2022-11-25  148.110001         151.070007         150.179993
# 8291 2022-11-28  144.220001         148.110001         151.070007
# 8292 2022-11-29  141.169998         144.220001         148.110001
# 8293 2022-11-30  148.029999         141.169998         144.220001
#
#       Trailing 3 day(s)  Trailing 4 day(s)  Trailing 5 day(s)  \
# 0                   NaN                NaN                NaN
# 1                   NaN                NaN                NaN
# 2                   NaN                NaN                NaN
# 3              0.264886                NaN                NaN
# 4              0.266664           0.264886                NaN
# ...                 ...                ...                ...
# 8289         151.289993         150.720001         148.789993
# 8290         148.009995         151.289993         150.720001
# 8291         150.179993         148.009995         151.289993
# 8292         151.070007         150.179993         148.009995
# 8293         148.110001         151.070007         150.179993
#
#       Trailing 6 day(s)  Trailing 7 day(s)  Trailing 8 day(s)  \
# 0                   NaN                NaN                NaN
# 1                   NaN                NaN                NaN
# 2                   NaN                NaN                NaN
# 3                   NaN                NaN                NaN
# 4                   NaN                NaN                NaN
# ...                 ...                ...                ...
# 8289         150.039993         148.279999         149.699997
# 8290         148.789993         150.039993         148.279999
# 8291         150.720001         148.789993         150.039993
# 8292         151.289993         150.720001         148.789993
# 8293         148.009995         151.289993         150.720001
#
#       Trailing 9 day(s)  Trailing 10 day(s)
# 0                   NaN                 NaN
# 1                   NaN                 NaN
# 2                   NaN                 NaN
# 3                   NaN                 NaN
# 4                   NaN                 NaN
# ...                 ...                 ...
# 8289         146.869995          134.869995
# 8290         149.699997          146.869995
# 8291         148.279999          149.699997
# 8292         150.039993          148.279999
# 8293         148.789993          150.039993
#
# [8294 rows x 12 columns]

# %%
# Prev change is today's change
df['Prev Change'] = (((df['Close'].shift(1)) / (df['Close']) - 1) * 100).fillna(0)
# % change is tomorrow's change
df['% Change'] = (((df['Close'].shift(-1)) / (df['Close']) - 1) * 100).fillna(0)
df
# Out:
#            Date       Close  Trailing 1 day(s)  Trailing 2 day(s)  \
# 0    1990-01-02    0.264886                NaN                NaN
# 1    1990-01-03    0.266664           0.264886                NaN
# 2    1990-01-04    0.267553           0.266664           0.264886
# 3    1990-01-05    0.268442           0.267553           0.266664
# 4    1990-01-08    0.270220           0.268442           0.267553
# ...         ...         ...                ...                ...
# 8289 2022-11-23  151.070007         150.179993         148.009995
# 8290 2022-11-25  148.110001         151.070007         150.179993
# 8291 2022-11-28  144.220001         148.110001         151.070007
# 8292 2022-11-29  141.169998         144.220001         148.110001
# 8293 2022-11-30  148.029999         141.169998         144.220001
#
#       Trailing 3 day(s)  Trailing 4 day(s)  Trailing 5 day(s)  \
# 0                   NaN                NaN                NaN
# 1                   NaN                NaN                NaN
# 2                   NaN                NaN                NaN
# 3              0.264886                NaN                NaN
# 4              0.266664           0.264886                NaN
# ...                 ...                ...                ...
# 8289         151.289993         150.720001         148.789993
# 8290         148.009995         151.289993         150.720001
# 8291         150.179993         148.009995         151.289993
# 8292         151.070007         150.179993         148.009995
# 8293         148.110001         151.070007         150.179993
#
#       Trailing 6 day(s)  Trailing 7 day(s)  Trailing 8 day(s)  \
# 0                   NaN                NaN                NaN
# 1                   NaN                NaN                NaN
# 2                   NaN                NaN                NaN
# 3                   NaN                NaN                NaN
# 4                   NaN                NaN                NaN
# ...                 ...                ...                ...
# 8289         150.039993         148.279999         149.699997
# 8290         148.789993         150.039993         148.279999
# 8291         150.720001         148.789993         150.039993
# 8292         151.289993         150.720001         148.789993
# 8293         148.009995         151.289993         150.720001
#
#       Trailing 9 day(s)  Trailing 10 day(s)  Prev Change  % Change
# 0                   NaN                 NaN     0.000000  0.671089
# 1                   NaN                 NaN    -0.666615  0.333648
# 2                   NaN                 NaN    -0.332539  0.332216
# 3                   NaN                 NaN    -0.331116  0.662165
# 4                   NaN                 NaN    -0.657809 -0.986747
# ...                 ...                 ...          ...       ...
# 8289         146.869995          134.869995    -0.589141 -1.959361
# 8290         149.699997          146.869995     1.998519 -2.626426
# 8291         148.279999          149.699997     2.697268 -2.114827
# 8292         150.039993          148.279999     2.160518  4.859390
# 8293         148.789993          150.039993    -4.634196  0.000000
#
# [8294 rows x 14 columns]

# %%
# 1 represents up, 0 represents down 
df['Direction'] = [1 if i > 0 else 0 for i in df['% Change']]
# Shift the direction back 1, so that Direction in a given row corresponds to where it is going tomorrow
df['Direction'] = df['Direction'].shift(-1)

df.tail()
# Out:
#            Date       Close  Trailing 1 day(s)  Trailing 2 day(s)  \
# 8289 2022-11-23  151.070007         150.179993         148.009995
# 8290 2022-11-25  148.110001         151.070007         150.179993
# 8291 2022-11-28  144.220001         148.110001         151.070007
# 8292 2022-11-29  141.169998         144.220001         148.110001
# 8293 2022-11-30  148.029999         141.169998         144.220001
#
#       Trailing 3 day(s)  Trailing 4 day(s)  Trailing 5 day(s)  \
# 8289         151.289993         150.720001         148.789993
# 8290         148.009995         151.289993         150.720001
# 8291         150.179993         148.009995         151.289993
# 8292         151.070007         150.179993         148.009995
# 8293         148.110001         151.070007         150.179993
#
#       Trailing 6 day(s)  Trailing 7 day(s)  Trailing 8 day(s)  \
# 8289         150.039993         148.279999         149.699997
# 8290         148.789993         150.039993         148.279999
# 8291         150.720001         148.789993         150.039993
# 8292         151.289993         150.720001         148.789993
# 8293         148.009995         151.289993         150.720001
#
#       Trailing 9 day(s)  Trailing 10 day(s)  Prev Change  % Change  Direction
# 8289         146.869995          134.869995    -0.589141 -1.959361        0.0
# 8290         149.699997          146.869995     1.998519 -2.626426        0.0
# 8291         148.279999          149.699997     2.697268 -2.114827        1.0
# 8292         150.039993          148.279999     2.160518  4.859390        0.0
# 8293         148.789993          150.039993    -4.634196  0.000000        NaN

# %%
# Plot the number of "up days" compared to the number of "down days"
plt.figure(figsize=(20,20))
sns.countplot(data=df, x='Direction').set_title("Direction Classifier")
# Out:
# Text(0.5, 1.0, 'Direction Classifier')

# %%
# Drop rows where no data exists
df.dropna(inplace=True)

# %%
# Plot correlation of the % change to current features
plt.figure(figsize=(10,5))
ax = df.corr()['% Change'].plot(kind='bar',title='correlation of target variable to features')
ax.set_ylabel('correlation')
# Out:
# Text(0, 0.5, 'correlation')

# %%
plt.figure(figsize=(30, 30))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
# Create X and y data
# Only want to use 10 days of lagging data and vix close for inputs
X = df.drop(axis=1, columns=['Date', '% Change', 'Direction'])
# Outputs should only be direction
y = df.Direction

# %%
X
# Out:
#            Close  Trailing 1 day(s)  Trailing 2 day(s)  Trailing 3 day(s)  \
# 10      0.247997           0.243553           0.245331           0.245331
# 11      0.236442           0.247997           0.243553           0.245331
# 12      0.230220           0.236442           0.247997           0.243553
# 13      0.243553           0.230220           0.236442           0.247997
# 14      0.236442           0.243553           0.230220           0.236442
# ...          ...                ...                ...                ...
# 8288  150.179993         148.009995         151.289993         150.720001
# 8289  151.070007         150.179993         148.009995         151.289993
# 8290  148.110001         151.070007         150.179993         148.009995
# 8291  144.220001         148.110001         151.070007         150.179993
# 8292  141.169998         144.220001         148.110001         151.070007
#
#       Trailing 4 day(s)  Trailing 5 day(s)  Trailing 6 day(s)  \
# 10             0.255998           0.267553           0.270220
# 11             0.245331           0.255998           0.267553
# 12             0.245331           0.245331           0.255998
# 13             0.243553           0.245331           0.245331
# 14             0.247997           0.243553           0.245331
# ...                 ...                ...                ...
# 8288         148.789993         150.039993         148.279999
# 8289         150.720001         148.789993         150.039993
# 8290         151.289993         150.720001         148.789993
# 8291         148.009995         151.289993         150.720001
# 8292         150.179993         148.009995         151.289993
#
#       Trailing 7 day(s)  Trailing 8 day(s)  Trailing 9 day(s)  \
# 10             0.268442           0.267553           0.266664
# 11             0.270220           0.268442           0.267553
# 12             0.267553           0.270220           0.268442
# 13             0.255998           0.267553           0.270220
# 14             0.245331           0.255998           0.267553
# ...                 ...                ...                ...
# 8288         149.699997         146.869995         134.869995
# 8289         148.279999         149.699997         146.869995
# 8290         150.039993         148.279999         149.699997
# 8291         148.789993         150.039993         148.279999
# 8292         150.720001         148.789993         150.039993
#
#       Trailing 10 day(s)  Prev Change
# 10              0.264886    -1.792015
# 11              0.266664     4.887275
# 12              0.267553     2.702471
# 13              0.268442    -5.474387
# 14              0.270220     3.007679
# ...                  ...          ...
# 8288          139.500000    -1.444932
# 8289          134.869995    -0.589141
# 8290          146.869995     1.998519
# 8291          149.699997     2.697268
# 8292          148.279999     2.160518
#
# [8283 rows x 12 columns]

# %%
y
# Out:
# 10      0.0
# 11      1.0
# 12      0.0
# 13      1.0
# 14      1.0
#        ...
# 8288    0.0
# 8289    0.0
# 8290    0.0
# 8291    1.0
# 8292    0.0
# Name: Direction, Length: 8283, dtype: float64

# %%
# Create train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=3)

# %%
X_train
# Out:
#           Close  Trailing 1 day(s)  Trailing 2 day(s)  Trailing 3 day(s)  \
# 2684   0.710665           0.716374           0.725888           0.723984
# 5557  13.063606          12.929353          12.780485          12.828581
# 1304   0.298054           0.288622           0.294280           0.303241
# 1539   0.215958           0.210251           0.207872           0.221667
# 4891   4.112002           4.050508           3.981401           3.729327
# ...         ...                ...                ...                ...
# 7171  45.224857          45.248821          45.718468          45.694496
# 2717   0.369128           0.391960           0.814363           0.744914
# 6410  29.238750          28.907524          28.993732          29.186575
# 1698   0.178855           0.175050           0.170293           0.159828
# 6004  16.586651          16.463949          16.650198          16.432644
#
#       Trailing 4 day(s)  Trailing 5 day(s)  Trailing 6 day(s)  \
# 2684           0.723033           0.711616           0.729693
# 5557          12.863899          12.884901          12.838933
# 1304           0.307957           0.309372           0.320690
# 1539           0.233083           0.230229           0.245450
# 4891           3.780473           3.831924           3.880023
# ...                 ...                ...                ...
# 7171          46.073090          45.821503          45.934124
# 2717           0.782969           0.814363           0.794385
# 6410          29.347641          29.520065          29.483765
# 1698           0.155072           0.160780           0.163634
# 6004          16.273315          16.319962          15.929606
#
#       Trailing 7 day(s)  Trailing 8 day(s)  Trailing 9 day(s)  \
# 2684           0.721130           0.730644           0.719228
# 5557          12.859333          12.726295          12.586556
# 1304           0.325878           0.321162           0.323992
# 1539           0.240694           0.232131           0.227375
# 4891           3.855668           3.726893           3.743026
# ...                 ...                ...                ...
# 7171          46.355835          46.480434          46.319893
# 2717           0.862883           0.929240           0.912354
# 6410          29.615355          29.556358          29.896660
# 1698           0.167440           0.175050           0.174099
# 6004          15.792193          15.686076          15.610015
#
#       Trailing 10 day(s)  Prev Change
# 2684            0.750622     0.803281
# 5557           12.519280    -1.027691
# 1304            0.330123    -3.164654
# 1539            0.243072    -2.642982
# 4891            3.637693    -1.495461
# ...                  ...          ...
# 7171           45.965275     0.052988
# 2717            0.923294     6.185372
# 6410           29.955645    -1.132833
# 1698            0.183613    -2.127559
# 6004           15.527371    -0.739761
#
# [6626 rows x 12 columns]

# %%
y_train
# Out:
# 2684    1.0
# 5557    0.0
# 1304    0.0
# 1539    0.0
# 4891    1.0
#        ...
# 7171    1.0
# 2717    1.0
# 6410    0.0
# 1698    0.0
# 6004    1.0
# Name: Direction, Length: 6626, dtype: float64

# %%
lr = LogisticRegression(random_state = 2)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=2)

# %% [markdown]
# ### View test results

# %%
train_accuracy = lr.score(X_train, y_train)
test_accuracy = lr.score(X_test, y_test)
print('Accuracy in Train set   : {:.2f}'.format(train_accuracy), 
      'Accuracy in Test  set   : {:.2f}'.format(test_accuracy), sep='\n')
# Out:
# Accuracy in Train set   : 0.53
# Accuracy in Test  set   : 0.50

# %%
predictions = lr.predict(X_test)

# %%
# let's use a confusion matrix to easily evaluate results 
from sklearn.metrics import confusion_matrix as cm, ConfusionMatrixDisplay
score = round(accuracy_score(y_test, predictions), 3)
cm1 = cm(y_test, predictions)
confusion_matrix_obj = ConfusionMatrixDisplay(cm1, display_labels=['Down', 'Up'])
confusion_matrix_obj.plot()
plt.title('Accuracy Score: {0}'.format(score), size = 15)
plt.show()

# %%
import seaborn as sns
sns.heatmap(cm1, annot=True)
# Out:
# <AxesSubplot:>
